# %%
"""

A Dolphin Population Model
Due 11pm on Thursday, Oct. 15, 2015

Name: Jacob Baca
Partner: Terry Tran

Build a model for a dolohin population over 150 years

"""

import random 
import math
import urllib2 
import re


t = 0

class Dolphins:
    
    def __init__(self, name, mother, father, sex):
        self.name = name
        self.mother = mother
        self.father = father
        self.sex = sex
        self.death = random.gauss(35, 5)
        self.age = 0
        self.timeafter = True
        print self.name + ' was created'
        
    def aging(self):
        self.age += 1
        if type(self.timeafter) == int:
            self.timeafter+=1
            if self.timeafter > 5:
                self.timeafter = True
        return self.age
    
    
    
    def die(self):
        print self.age, int(self.death)
        if self.age == int(self.death):
            return True
    
    def sexy_time(self, Dolphin):
        if type(self.timeafter) != bool:
            if self.timeafter <= 5:
                return False
        if self.sex == Dolphin.sex: #can't have the same sex
            return False 
        if (self.age < 8) or (Dolphin.age < 8): #above age of 8
            return False 
        if abs(self.age - Dolphin.age) >= 10: #no age difference greater than 10
            return False
        if (Dolphin.mother,Dolphin.father) == (self.mother,self.father):
            return False
        else:
            return True

################################################################################################################################################

def name_generator(sex):
    male_name_lst = []
    female_name_lst = []
    z = 0 #number of pages iterated through

    while z <=1: #iterates through baby-names website pages for names 

        m_names = 'http://www.prokerala.com/kids/baby-names/boy/page-' + str(z) + '.html'
        f_names = 'http://www.prokerala.com/kids/baby-names/girl/page-' + str(z) + '.html'
        
        #male names
        infile = urllib2.urlopen(m_names) 
        male_text = infile.read()   
        infile.close() 
        #print male_text

        #female names
        infile = urllib2.urlopen(f_names) 
        female_text = infile.read()   
        infile.close() 

        #finds all names and puts in list
        male_name_lst_temp = re.findall('ils">.*</s', male_text)
        male_name_lst += male_name_lst_temp
        female_name_lst_temp = re.findall('ils">.*</s', female_text)
        female_name_lst += female_name_lst_temp

        z+=1

    male_names = []
    for name in male_name_lst: # strips names of unnecessary characters
        string = name.lstrip('ils">').rstrip('</s')
        male_names.append(string)

    #print male_names

    female_names = []
    for name in female_name_lst: #same as above
        string = name.lstrip('ils">').rstrip('</s')
        female_names.append(string)

    #print female_names[20]
    
    m=0
    f=0
    if sex == 'male':
        while m < len(male_names):
            yield male_names[m]
            m+=1

    if sex == 'female':
        while f< len(female_names):
            yield female_names[f]
            f+=1

###################################################################################################################
            
male_generator = name_generator('male')
female_generator = name_generator('female')

def creation(mother, father):
    if Dolphins.sexy_time(mother, father):
        gender = random.random([male, female])
        print gender
        if gender == 'male':
            male_gener = male_generator.next()
            print male_gener
            male_gener = Dolphins(male_gener, mother, father, gender)
        else:
            female_gener = female_generator.next()
            female_gener = Dolphins(female_gener, mother, father, gender)
            
        mother.timeafter = 0
        father.timeafter = 0
    else:
        print 'Cannot procreate.'

#these are the original 4 dolphin in the population:
Jeffery = Dolphins('Jeffery', 'Todd Pinkins', 'Hilay sause', 'male')
Carrot = Dolphins('Carrot', 'Too Pin', 'Hilary Fartse', 'male')
Kayak = Dolphins('Kayak', 'Td kins', 'Hiary tersause', 'female')
Tiffany = Dolphins('Tiffany', 'dd Pis', 'Hil Fase', 'female')

dolph_dic={'Jeffery':Jeffery, 'Carrot':Carrot, 'Kayak':Kayak, 'Tiffany':Tiffany}


for i in range(151):
    for dolphin in dolph_dic:
        print dolphin
        dol = dolph_dic[str(dolphin)]
        dol.aging()
        if dol.die() == True:
            del dolph_dic[str(dolphin)]
            
        print dolph_dic.keys()
            
        #print Jeffery.age, Carrot.age, Kayak.age, Tiffany.age
# Out:
# Jeffery was created
# Carrot was created
# Kayak was created
# Tiffany was created
# Kayak
# 1 41
# ['Kayak', 'Tiffany', 'Carrot', 'Jeffery']
# Tiffany
# 1 33
# ['Kayak', 'Tiffany', 'Carrot', 'Jeffery']
# Carrot
# 1 37
# ['Kayak', 'Tiffany', 'Carrot', 'Jeffery']
# Jeffery
# 1 36
# ['Kayak', 'Tiffany', 'Carrot', 'Jeffery']
# Kayak
# 2 41
# ['Kayak', 'Tiffany', 'Carrot', 'Jeffery']
# Tiffany
# 2 33
# ['Kayak', 'Tiffany', 'Carrot', 'Jeffery']
# Carrot
# 2 37
# ['Kayak', 'Tiffany', 'Carrot', 'Jeffery']
# Jeffery
# 2 36
# ['Kayak', 'Tiffany', 'Carrot', 'Jeffery']
# Kayak
# 3 41
# ['Kayak', 'Tiffany', 'Carrot', 'Jeffery']
# Tiffany
# 3 33
# ['Kayak', 'Tiffany', 'Carrot', 'Jeffery']
# Carrot
# 3 37
# ['Kayak', 'Tiffany', 'Carrot', 'Jeffery']
# Jeffery
# 3 36
# ['Kayak', 'Tiffany', 'Carrot', 'Jeffery']
# Kayak
# 4 41
# ['Kayak', 'Tiffany', 'Carrot', 'Jeffery']
# Tiffany
# 4 33
# ['Kayak', 'Tiffany', 'Carrot', 'Jeffery']
# Carrot
# 4 37
# ['Kayak', 'Tiffany', 'Carrot', 'Jeffery']
# Jeffery
# 4 36
# ['Kayak', 'Tiffany', 'Carrot', 'Jeffery']
# Kayak
# 5 41
# ['Kayak', 'Tiffany', 'Carrot', 'Jeffery']
# Tiffany
# 5 33
# ['Kayak', 'Tiffany', 'Carrot', 'Jeffery']
# Carrot
# 5 37
# ['Kayak', 'Tiffany', 'Carrot', 'Jeffery']
# Jeffery
# 5 36
# ['Kayak', 'Tiffany', 'Carrot', 'Jeffery']
# Kayak
# 6 41
# ['Kayak', 'Tiffany', 'Carrot', 'Jeffery']
# Tiffany
# 6 33
# ['Kayak', 'Tiffany', 'Carrot', 'Jeffery']
# Carrot
# 6 37
# ['Kayak', 'Tiffany', 'Carrot', 'Jeffery']
# Jeffery
# 6 36
# ['Kayak', 'Tiffany', 'Carrot', 'Jeffery']
# Kayak
# 7 41
# ['Kayak', 'Tiffany', 'Carrot', 'Jeffery']
# Tiffany
# 7 33
# ['Kayak', 'Tiffany', 'Carrot', 'Jeffery']
# Carrot
# 7 37
# ['Kayak', 'Tiffany', 'Carrot', 'Jeffery']
# Jeffery
# 7 36
# ['Kayak', 'Tiffany', 'Carrot', 'Jeffery']
# Kayak
# 8 41
# ['Kayak', 'Tiffany', 'Carrot', 'Jeffery']
# Tiffany
# 8 33
# ['Kayak', 'Tiffany', 'Carrot', 'Jeffery']
# Carrot
# 8 37
# ['Kayak', 'Tiffany', 'Carrot', 'Jeffery']
# Jeffery
# 8 36
# ['Kayak', 'Tiffany', 'Carrot', 'Jeffery']
# Kayak
# 9 41
# ['Kayak', 'Tiffany', 'Carrot', 'Jeffery']
# Tiffany
# 9 33
# ['Kayak', 'Tiffany', 'Carrot', 'Jeffery']
# Carrot
# 9 37
# ['Kayak', 'Tiffany', 'Carrot', 'Jeffery']
# Jeffery
# 9 36
# ['Kayak', 'Tiffany', 'Carrot', 'Jeffery']
# Kayak
# 10 41
# ['Kayak', 'Tiffany', 'Carrot', 'Jeffery']
# Tiffany
# 10 33
# ['Kayak', 'Tiffany', 'Carrot', 'Jeffery']
# Carrot
# 10 37
# ['Kayak', 'Tiffany', 'Carrot', 'Jeffery']
# Jeffery
# 10 36
# ['Kayak', 'Tiffany', 'Carrot', 'Jeffery']
# Kayak
# 11 41
# ['Kayak', 'Tiffany', 'Carrot', 'Jeffery']
# Tiffany
# 11 33
# ['Kayak', 'Tiffany', 'Carrot', 'Jeffery']
# Carrot
# 11 37
# ['Kayak', 'Tiffany', 'Carrot', 'Jeffery']
# Jeffery
# 11 36
# ['Kayak', 'Tiffany', 'Carrot', 'Jeffery']
# Kayak
# 12 41
# ['Kayak', 'Tiffany', 'Carrot', 'Jeffery']
# Tiffany
# 12 33
# ['Kayak', 'Tiffany', 'Carrot', 'Jeffery']
# Carrot
# 12 37
# ['Kayak', 'Tiffany', 'Carrot', 'Jeffery']
# Jeffery
# 12 36
# ['Kayak', 'Tiffany', 'Carrot', 'Jeffery']
# Kayak
# 13 41
# ['Kayak', 'Tiffany', 'Carrot', 'Jeffery']
# Tiffany
# 13 33
# ['Kayak', 'Tiffany', 'Carrot', 'Jeffery']
# Carrot
# 13 37
# ['Kayak', 'Tiffany', 'Carrot', 'Jeffery']
# Jeffery
# 13 36
# ['Kayak', 'Tiffany', 'Carrot', 'Jeffery']
# Kayak
# 14 41
# ['Kayak', 'Tiffany', 'Carrot', 'Jeffery']
# Tiffany
# 14 33
# ['Kayak', 'Tiffany', 'Carrot', 'Jeffery']
# Carrot
# 14 37
# ['Kayak', 'Tiffany', 'Carrot', 'Jeffery']
# Jeffery
# 14 36
# ['Kayak', 'Tiffany', 'Carrot', 'Jeffery']
# Kayak
# 15 41
# ['Kayak', 'Tiffany', 'Carrot', 'Jeffery']
# Tiffany
# 15 33
# ['Kayak', 'Tiffany', 'Carrot', 'Jeffery']
# Carrot
# 15 37
# ['Kayak', 'Tiffany', 'Carrot', 'Jeffery']
# Jeffery
# 15 36
# ['Kayak', 'Tiffany', 'Carrot', 'Jeffery']
# Kayak
# 16 41
# ['Kayak', 'Tiffany', 'Carrot', 'Jeffery']
# Tiffany
# 16 33
# ['Kayak', 'Tiffany', 'Carrot', 'Jeffery']
# Carrot
# 16 37
# ['Kayak', 'Tiffany', 'Carrot', 'Jeffery']
# Jeffery
# 16 36
# ['Kayak', 'Tiffany', 'Carrot', 'Jeffery']
# Kayak
# 17 41
# ['Kayak', 'Tiffany', 'Carrot', 'Jeffery']
# Tiffany
# 17 33
# ['Kayak', 'Tiffany', 'Carrot', 'Jeffery']
# Carrot
# 17 37
# ['Kayak', 'Tiffany', 'Carrot', 'Jeffery']
# Jeffery
# 17 36
# ['Kayak', 'Tiffany', 'Carrot', 'Jeffery']
# Kayak
# 18 41
# ['Kayak', 'Tiffany', 'Carrot', 'Jeffery']
# Tiffany
# 18 33
# ['Kayak', 'Tiffany', 'Carrot', 'Jeffery']
# Carrot
# 18 37
# ['Kayak', 'Tiffany', 'Carrot', 'Jeffery']
# Jeffery
# 18 36
# ['Kayak', 'Tiffany', 'Carrot', 'Jeffery']
# Kayak
# 19 41
# ['Kayak', 'Tiffany', 'Carrot', 'Jeffery']
# Tiffany
# 19 33
# ['Kayak', 'Tiffany', 'Carrot', 'Jeffery']
# Carrot
# 19 37
# ['Kayak', 'Tiffany', 'Carrot', 'Jeffery']
# Jeffery
# 19 36
# ['Kayak', 'Tiffany', 'Carrot', 'Jeffery']
# Kayak
# 20 41
# ['Kayak', 'Tiffany', 'Carrot', 'Jeffery']
# Tiffany
# 20 33
# ['Kayak', 'Tiffany', 'Carrot', 'Jeffery']
# Carrot
# 20 37
# ['Kayak', 'Tiffany', 'Carrot', 'Jeffery']
# Jeffery
# 20 36
# ['Kayak', 'Tiffany', 'Carrot', 'Jeffery']
# Kayak
# 21 41
# ['Kayak', 'Tiffany', 'Carrot', 'Jeffery']
# Tiffany
# 21 33
# ['Kayak', 'Tiffany', 'Carrot', 'Jeffery']
# Carrot
# 21 37
# ['Kayak', 'Tiffany', 'Carrot', 'Jeffery']
# Jeffery
# 21 36
# ['Kayak', 'Tiffany', 'Carrot', 'Jeffery']
# Kayak
# 22 41
# ['Kayak', 'Tiffany', 'Carrot', 'Jeffery']
# Tiffany
# 22 33
# ['Kayak', 'Tiffany', 'Carrot', 'Jeffery']
# Carrot
# 22 37
# ['Kayak', 'Tiffany', 'Carrot', 'Jeffery']
# Jeffery
# 22 36
# ['Kayak', 'Tiffany', 'Carrot', 'Jeffery']
# Kayak
# 23 41
# ['Kayak', 'Tiffany', 'Carrot', 'Jeffery']
# Tiffany
# 23 33
# ['Kayak', 'Tiffany', 'Carrot', 'Jeffery']
# Carrot
# 23 37
# ['Kayak', 'Tiffany', 'Carrot', 'Jeffery']
# Jeffery
# 23 36
# ['Kayak', 'Tiffany', 'Carrot', 'Jeffery']
# Kayak
# 24 41
# ['Kayak', 'Tiffany', 'Carrot', 'Jeffery']
# Tiffany
# 24 33
# ['Kayak', 'Tiffany', 'Carrot', 'Jeffery']
# Carrot
# 24 37
# ['Kayak', 'Tiffany', 'Carrot', 'Jeffery']
# Jeffery
# 24 36
# ['Kayak', 'Tiffany', 'Carrot', 'Jeffery']
# Kayak
# 25 41
# ['Kayak', 'Tiffany', 'Carrot', 'Jeffery']
# Tiffany
# 25 33
# ['Kayak', 'Tiffany', 'Carrot', 'Jeffery']
# Carrot
# 25 37
# ['Kayak', 'Tiffany', 'Carrot', 'Jeffery']
# Jeffery
# 25 36
# ['Kayak', 'Tiffany', 'Carrot', 'Jeffery']
# Kayak
# 26 41
# ['Kayak', 'Tiffany', 'Carrot', 'Jeffery']
# Tiffany
# 26 33
# ['Kayak', 'Tiffany', 'Carrot', 'Jeffery']
# Carrot
# 26 37
# ['Kayak', 'Tiffany', 'Carrot', 'Jeffery']
# Jeffery
# 26 36
# ['Kayak', 'Tiffany', 'Carrot', 'Jeffery']
# Kayak
# 27 41
# ['Kayak', 'Tiffany', 'Carrot', 'Jeffery']
# Tiffany
# 27 33
# ['Kayak', 'Tiffany', 'Carrot', 'Jeffery']
# Carrot
# 27 37
# ['Kayak', 'Tiffany', 'Carrot', 'Jeffery']
# Jeffery
# 27 36
# ['Kayak', 'Tiffany', 'Carrot', 'Jeffery']
# Kayak
# 28 41
# ['Kayak', 'Tiffany', 'Carrot', 'Jeffery']
# Tiffany
# 28 33
# ['Kayak', 'Tiffany', 'Carrot', 'Jeffery']
# Carrot
# 28 37
# ['Kayak', 'Tiffany', 'Carrot', 'Jeffery']
# Jeffery
# 28 36
# ['Kayak', 'Tiffany', 'Carrot', 'Jeffery']
# Kayak
# 29 41
# ['Kayak', 'Tiffany', 'Carrot', 'Jeffery']
# Tiffany
# 29 33
# ['Kayak', 'Tiffany', 'Carrot', 'Jeffery']
# Carrot
# 29 37
# ['Kayak', 'Tiffany', 'Carrot', 'Jeffery']
# Jeffery
# 29 36
# ['Kayak', 'Tiffany', 'Carrot', 'Jeffery']
# Kayak
# 30 41
# ['Kayak', 'Tiffany', 'Carrot', 'Jeffery']
# Tiffany
# 30 33
# ['Kayak', 'Tiffany', 'Carrot', 'Jeffery']
# Carrot
# 30 37
# ['Kayak', 'Tiffany', 'Carrot', 'Jeffery']
# Jeffery
# 30 36
# ['Kayak', 'Tiffany', 'Carrot', 'Jeffery']
# Kayak
# 31 41
# ['Kayak', 'Tiffany', 'Carrot', 'Jeffery']
# Tiffany
# 31 33
# ['Kayak', 'Tiffany', 'Carrot', 'Jeffery']
# Carrot
# 31 37
# ['Kayak', 'Tiffany', 'Carrot', 'Jeffery']
# Jeffery
# 31 36
# ['Kayak', 'Tiffany', 'Carrot', 'Jeffery']
# Kayak
# 32 41
# ['Kayak', 'Tiffany', 'Carrot', 'Jeffery']
# Tiffany
# 32 33
# ['Kayak', 'Tiffany', 'Carrot', 'Jeffery']
# Carrot
# 32 37
# ['Kayak', 'Tiffany', 'Carrot', 'Jeffery']
# Jeffery
# 32 36
# ['Kayak', 'Tiffany', 'Carrot', 'Jeffery']
# Kayak
# 33 41
# ['Kayak', 'Tiffany', 'Carrot', 'Jeffery']
# Tiffany
# 33 33
# ['Kayak', 'Carrot', 'Jeffery']
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-65-fd78e99db0f0> in <module>()
#     150
#     151 for i in range(151):
# --> 152     for dolphin in dolph_dic:
#     153         print dolphin
#     154         dol = dolph_dic[str(dolphin)]
#
# RuntimeError: dictionary changed size during iteration
