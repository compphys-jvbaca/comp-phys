# %%
"""

A Dolphin Population Model
Due 11pm on Thursday, Oct. 15, 2015

Name: Jacob Baca
Partner: Terry Tran

Build a model for a dolohin population over 150 years

"""

import random 
import math


t = 0

class Dolphins:
    
    def __init__(self, name, mother, father):
        self.name = name
        self.mother = mother
        self.father = father
        self.sex = random.random([male, female])
        self.death = random.gauss(35, 5)
        self.age = 0
        self.timeafter = '0'
        
    def aging(self):
        self.age += 1
        if self.timeafter = 
        return self.age
    
    
    
    def die(self):
        if self.age >= self.death:
            return True
    
    def sexy_time(self, Dolphin):
        if self.timeafter < 5:
            return False
        if self.sex == Dolphin.sex: #can't have the same sex
            return False 
        if (self.age < 8) or (Dolphin.age < 8): #above age of 8
            return False 
        if abs(self.age - Dolphin.age) >= 10: #no age difference greater than 10
            return False
        if (Dolphin.mother,Dolphin.father) ==\ #not the same parents
           (self.mother,self.father):
            return False
        else:
            return True


    #def __call__(self):
        # nothing yet
        
    #def __str__(self): #input print instantiated object and this will return aspecified string. 
        # nothing yet 
        
def creation(mother, father):
    if sexy_time(mother, father):
        name = Dolphins(name, mother, father)
        mother.timeafter = 0
        father.timeafter = 0
        
Tori = Dolphins('Tori', 'Canopy', 'Yamaha')
Benjamin = Dolphins('Benjamin', 'Python', 'Gerber')
Tiffany = Dolphins('Tiffany', 'Eclipse', 'Microsoft')
Zowchonng = Dolphins('Zowchonng', 'Seepluslplus', 'Macintosh')
# Out:
#  0 Canopy Yamaha Harvey
# 1 Canopy Yamaha Harvey
# 2 Canopy Yamaha Harvey
# 3 Canopy Yamaha Harvey
# 4 Canopy Yamaha Harvey
# 5 Canopy Yamaha Harvey
# 6 Canopy Yamaha Harvey
# 7 Canopy Yamaha Harvey
# 8 Canopy Yamaha Harvey
# 9 Canopy Yamaha Harvey
# 10 Canopy Yamaha Harvey
# 11 Canopy Yamaha Harvey
# 12 Canopy Yamaha Harvey
# 13 Canopy Yamaha Harvey
# 14 Canopy Yamaha Harvey
# 15 Canopy Yamaha Harvey
# 16 Canopy Yamaha Harvey
# 17 Canopy Yamaha Harvey
# 18 Canopy Yamaha Harvey
# 19 Canopy Yamaha Harvey
# 20 Canopy Yamaha Harvey
# 21 Canopy Yamaha Harvey
# 22 Canopy Yamaha Harvey
# 23 Canopy Yamaha Harvey
# 24 Canopy Yamaha Harvey
# 25 Canopy Yamaha Harvey
# 26 Canopy Yamaha Harvey
# 27 Canopy Yamaha Harvey
# 28 Canopy Yamaha Harvey
# 29 Canopy Yamaha Harvey
# 30 Canopy Yamaha Harvey
# 31 Canopy Yamaha Harvey
# 32 Canopy Yamaha Harvey
# 33 Canopy Yamaha Harvey
# 34 Canopy Yamaha Harvey
# 35 Canopy Yamaha Harvey
# 36 Canopy Yamaha Harvey
# 37 Canopy Yamaha Harvey
# ...
