# %%
from math import pi
s = 0 
max = 1000 

for i in range (max):
    s+= 1./(i+1)**2
    
print 'with the for loop, the sum is', s

i=1
s=0

while i <= max:
    s += 1./i**2
    i = i+1
print 'correct answer:', pi**2/6
# Out:
# with the for loop, the sum is 1.64393456668
# correct answer: 1.64493406685

# %%
a = 'hello'
space = ' '
b = 'world'
print a + space +b
# Out:
# hello world

# %%
print bool(0.)
print bool(98)
print bool(23)
print bool(34)
print bool(55)
print bool(20)
print bool(1)
# Out:
# False
# True
# True
# True
# True
# True
# True

# %%
Cdegrees = [-20, -15,-5,5,10,15,20]
for C in Cdegrees:
    print C in Cdegrees
    F = (9.0/5)*C +32.
    print '%5d %5.1f' % (C,F)
# Out:
# True
#   -20  -4.0
# True
#   -15   5.0
# True
#    -5  23.0
# True
#     5  41.0
# True
#    10  50.0
# True
#    15  59.0
# True
#    20  68.0

# %%
#breakout: convert the above into a while loop

c = -100
print ' C    F'
while c <= 100:
    f = (9.0/5)*c +32.
    print '%5d %5.1f' % (c,f)
    c += 5
# Out:
#  C    F
#  -100 -148.0
#   -95 -139.0
#   -90 -130.0
#   -85 -121.0
#   -80 -112.0
#   -75 -103.0
#   -70 -94.0
#   -65 -85.0
#   -60 -76.0
#   -55 -67.0
#   -50 -58.0
#   -45 -49.0
#   -40 -40.0
#   -35 -31.0
#   -30 -22.0
#   -25 -13.0
#   -20  -4.0
#   -15   5.0
#   -10  14.0
#    -5  23.0
#     0  32.0
#     5  41.0
#    10  50.0
#    15  59.0
#    20  68.0
#    25  77.0
#    30  86.0
#    35  95.0
#    40 104.0
#    45 113.0
#    50 122.0
#    55 131.0
#    60 140.0
#    65 149.0
#    70 158.0
#    75 167.0
#    80 176.0
#    85 185.0
#    90 194.0
#    95 203.0
#   100 212.0

# %%
import copy 
c= copy.comp(a)
print 'c== a:', c ==a

# %%
#lost the variables...

a.append(1.4e5)
print 'a:', a
print 'r:', r
print 's:', s
print 'c:', c

#there is a huge difference between r and s

# %%
range( 1, 3, 5)
# Out:
# [1]

# %%
for i, c in enumerate(Cdegrees):
    Cdegrees[i] = c+2*1
print Cdegrees, Cdegrees[i]
# Out:
# [-16, -11, -1, 9, 14, 19, 24] 24

# %%
# convert degrees celsius from -5 to 5 in increments of -0.5


n=0.5
while n<=20:
    Cdegrees= range (-5,5,n)
    print Cdegrees
    n+=0.5
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-176e6acc78d4> in <module>()
#       4 n=0.5
#       5 while n<=20:
# ----> 6     Cdegrees= range (-5,5,n)
#       7     print Cdegrees
#       8     n+=0.5
#
# TypeError: range() integer step argument expected, got float.

# %%
n=21
Fdegrees=[(-5.+.5*i)*(9.0/5)+32 for i in range(n)]

# %%
zip(Cdegrees, Cdegrees)
for C, F in zip(Cdegrees, Fdegrees):
    print '%5.1f %5.1f' % (C,F)
# Out:
# -16.0  23.0
# -11.0  23.9
#  -1.0  24.8
#   9.0  25.7
#  14.0  26.6
#  19.0  27.5
#  24.0  28.4

# %%
for C, F in zip(Cdegrees, Fdegrees):
    print "{.5.1f}, {.5.1f}".format(C,F)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-25-6448a81dbb4c> in <module>()
#       1 for C, F in zip(Cdegrees, Fdegrees):
# ----> 2     print "{.5.1f}, {.5.1f}".format(C,F)
#       3
#
# AttributeError: 'int' object has no attribute '5'

# %%
[C/F for C, F in zip(Cdegrees, Fdegrees)]
# Out:
# [-0.6956521739130435,
#  -0.46025104602510464,
#  -0.04032258064516129,
#  0.3501945525291829,
#  0.5263157894736842,
#  0.6909090909090909,
#  0.8450704225352114]

# %%
[[C,F] for C,F in zip(Cdegrees, Fdegrees)]
# Out:
# [[-16, 23.0],
#  [-11, 23.9],
#  [-1, 24.8],
#  [9, 25.7],
#  [14, 26.6],
#  [19, 27.5],
#  [24, 28.4]]

# %%
table1=[[1,1,3,5,7,8,5,8,4,7,4,5,8,5,7,7,4,6,78,5,8,6,4,7,6,3,56]
table1[0:2][0]
# Out:
# 1

# %%
scores = []
scores.append([12,16,11,12],[9],[6,9,7,4,3,2,3])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-2-e4ad5a610b0f> in <module>()
#       1 scores = []
# ----> 2 scores.append([12,16,11,12],[9],[6,9,7,4,3,2,3])
#
# TypeError: append() takes exactly one argument (3 given)

# %%
def F(C):
    return (9./5)*C + 32.
a = 10
F1 = F(a)
print F1
# Out:
# 50.0
